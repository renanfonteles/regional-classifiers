# %% [markdown]
# ### 1. Regional OLS Results

# %%
import numpy as np
import pandas as pd

# loading simulation results
df_results = pd.read_csv('results/regional-results/ROLS - all - n_res=100 - 2019-07-10.csv')
df_results.head()
# Out:
#   dataset_name  random_state  alpha0  sigma0  nEpochs              cm_tr  \
# 0         vc2c     127815836     0.1     3.0      100  [156  13  15  64]
# 1         vc2c     127815836     0.1    10.0      100  [153  16  16  63]
# 2         vc2c     127815836     0.1     6.5      100  [162   7  21  58]
# 3         vc2c     127815836     0.1    10.0      300  [157  12  21  58]
# 4         vc2c     127815836     0.1     6.5      300  [155  14  19  60]
#
#            cm_ts
# 0  [32  9  7 14]
# 1  [32  9  6 15]
# 2  [34  7  9 12]
# 3  [32  9  8 13]
# 4  [33  8  7 14]

# %% [markdown]
# Results for each data set:

# %%
from load_dataset import datasets

test_size     = 0.2
scaleType     = 'min-max'
n_resamplings = 100

num = 3

alphas = [0.1, 0.3, 0.5]     # np.linspace(0.1, 0.5,  num=num).tolist()
sigmas = [3.0, 6.5, 10.0]    # np.linspace(3,    10,   num=num).tolist()
epochs = [100]               # np.linspace(100,  500, num=num, dtype='int').tolist()
    
som_params = [
    {
     "alpha0"  : alpha0
    ,"sigma0"  : sigma0
    ,"nEpochs" : nEpochs
    }
    for alpha0       in alphas
    for sigma0       in sigmas
    for nEpochs      in epochs
]

header = list(som_params[0].keys()) + ['Minimum', 'Maximum', 'Median', 'Mean', 'Std. Deviation']

df_ds = {}
for dataset_name in datasets: # For this specific dataset
    print(dataset_name)
    df = df_results.loc[df_results['dataset_name'] == dataset_name] # get simulation results

    count = 0
    df_data   = np.zeros((len(som_params), len(header))) # matriz que guardará resultados numéricos
    for params in som_params:
        df_case = df.loc[(df['alpha0']  == params['alpha0']) & 
                         (df['sigma0']  == params['sigma0']) &
                         (df['nEpochs'] == params['nEpochs'])]

        # converting confusion matrix from string to numpy array
        cm_ts = np.array([[int(x) for x in result[1:-1].split()] for result in df_case['cm_ts'].values])

        #data = cm_ts
        length = cm_ts.shape[1]
        cm_side = int(np.sqrt(length))

        acc   = [0]*len(cm_ts)
        for i in range(len(cm_ts)):
            cm = np.reshape(cm_ts[i], (cm_side,cm_side))
            acc[i] = np.trace(cm)/np.sum(cm)

        df_data[count,:] = np.matrix([
            params['alpha0'], params['sigma0'], params['nEpochs'],
            min(acc), max(acc), np.median(acc), np.mean(acc), np.std(acc)])
        count+=1


    df_ds[dataset_name] = pd.DataFrame(df_data, columns=header)
    print(df_ds[dataset_name].head()) # TODO: display
    print('-'*100,'\n'*2)
# Out:
# vc2c
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.677419  0.919355  0.838710  0.827097
# 1     0.1     6.5    100.0  0.693548  0.903226  0.838710  0.828871
# 2     0.1    10.0    100.0  0.725806  0.951613  0.838710  0.832419
# 3     0.3     3.0    100.0  0.709677  0.935484  0.830645  0.829839
# 4     0.3     6.5    100.0  0.725806  0.935484  0.838710  0.832097
#
#    Std. Deviation
# 0        0.050134
# 1        0.046573
# 2        0.045040
# 3        0.045240
# 4        0.047470
# ----------------------------------------------------------------------------------------------------
#
#
# vc3c
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.645161  0.919355  0.822581  0.811129
# 1     0.1     6.5    100.0  0.693548  0.919355  0.814516  0.810806
# 2     0.1    10.0    100.0  0.709677  0.903226  0.822581  0.814032
# 3     0.3     3.0    100.0  0.693548  0.919355  0.822581  0.815645
# 4     0.3     6.5    100.0  0.693548  0.903226  0.822581  0.812742
#
#    Std. Deviation
# 0        0.049624
# 1        0.044748
# 2        0.042334
# 3        0.043832
# 4        0.048650
# ----------------------------------------------------------------------------------------------------
#
#
# wf24f
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.793040  0.878205  0.850733  0.849762
# 1     0.1     6.5    100.0  0.818681  0.884615  0.854396  0.853965
# 2     0.1    10.0    100.0  0.819597  0.883700  0.852564  0.852106
# 3     0.3     3.0    100.0  0.816850  0.885531  0.853938  0.854551
# 4     0.3     6.5    100.0  0.820513  0.881868  0.855769  0.854295
#
#    Std. Deviation
# 0        0.015719
# 1        0.012983
# 2        0.012776
# 3        0.014515
# 4        0.012159
# ----------------------------------------------------------------------------------------------------
#
#
# wf4f
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.839744  0.930403  0.873626  0.877564
# 1     0.1     6.5    100.0  0.840659  0.935897  0.876374  0.879954
# 2     0.1    10.0    100.0  0.838828  0.925824  0.877289  0.878663
# 3     0.3     3.0    100.0  0.842491  0.934982  0.876832  0.880165
# 4     0.3     6.5    100.0  0.831502  0.929487  0.875000  0.878645
#
#    Std. Deviation
# 0        0.019076
# 1        0.021112
# 2        0.018983
# 3        0.019842
# 4        0.018760
# ----------------------------------------------------------------------------------------------------
#
#
# wf2f
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.769231  0.960623  0.908883  0.911016
# 1     0.1     6.5    100.0  0.855311  0.957875  0.907509  0.907326
# 2     0.1    10.0    100.0  0.862637  0.959707  0.908883  0.910046
# 3     0.3     3.0    100.0  0.804029  0.964286  0.907509  0.906364
# 4     0.3     6.5    100.0  0.847985  0.958791  0.905678  0.905696
#
#    Std. Deviation
# 0        0.023783
# 1        0.017636
# 2        0.015775
# 3        0.020521
# 4        0.016253
# ----------------------------------------------------------------------------------------------------
#
#
# pk
#    alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# 0     0.1     3.0    100.0  0.717949  1.000000  0.871795  0.860513
# 1     0.1     6.5    100.0  0.692308  1.000000  0.871795  0.865128
# 2     0.1    10.0    100.0  0.666667  1.000000  0.871795  0.863077
# 3     0.3     3.0    100.0  0.692308  0.974359  0.871795  0.864359
# 4     0.3     6.5    100.0  0.717949  0.974359  0.871795  0.864103
#
#    Std. Deviation
# 0        0.059177
# 1        0.062030
# 2        0.057015
# 3        0.059617
# 4        0.057507
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Taking the best values by higher mean in accuracy.

# %%
data = np.array([df.sort_values('Mean', ascending=False).iloc[0,:].values for df in df_ds.values()])
idx_label = list(df_ds.keys())
df_rols = pd.DataFrame(data, columns=header, index=[idx_label])
df_rols
# Out:
#        alpha0  sigma0  nEpochs   Minimum   Maximum    Median      Mean  \
# vc2c      0.1    10.0    100.0  0.725806  0.951613  0.838710  0.832419
# vc3c      0.3    10.0    100.0  0.677419  0.919355  0.822581  0.816452
# wf24f     0.5    10.0    100.0  0.812271  0.888278  0.858516  0.858178
# wf4f      0.5    10.0    100.0  0.836081  0.938645  0.879579  0.882894
# wf2f      0.1     3.0    100.0  0.769231  0.960623  0.908883  0.911016
# pk        0.3    10.0    100.0  0.692308  0.974359  0.871795  0.868974
#
#        Std. Deviation
# vc2c         0.045040
# vc3c         0.048750
# wf24f        0.013810
# wf4f         0.023216
# wf2f         0.023783
# pk           0.055576

# %% [markdown]
# # Globlal OLS

# %%
from multiprocessing import Pool
import tqdm

data = [None]*len(cases)

pool = Pool()
data =[result for result in tqdm.tqdm(pool.imap_unordered(evalGOLS,cases), total=len(cases))]
pool.close()
pool.join()

results = np.vstack(data)
header  = ["dataset_name", "random_state", "cm_tr", "cm_ts"]
results_df = pd.DataFrame(results, columns=header)
# Out:
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]

# %%
results_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 results_df.head()
#
# NameError: name 'results_df' is not defined

# %% [markdown]
# Processing results (taking the best values by higher mean in accuracy):

# %%
header = ['Minimum', 'Maximum', 'Median', 'Mean', 'Std. Deviation']

data      = np.zeros(( len(datasets.keys()), len(header) ))
idx_label = [' ']*len(datasets.keys())
count=0
for dataset_name in datasets: # For this specific dataset
    df = results_df.loc[results_df['dataset_name'] == dataset_name] # get simulation results
    
    # converting confusion matrices to numpy matrix
    cm_ts = np.array([array for array in df['cm_ts'].values])
       
    length = cm_ts.shape[1]
    cm_side = int(np.sqrt(length))
    acc   = [0]*len(cm_ts)
    for i in range(len(cm_ts)):
        cm = np.reshape(cm_ts[i], (cm_side,cm_side))
        acc[i] = np.trace(cm)/np.sum(cm)

    data[count,:] = np.array([min(acc), max(acc), np.median(acc), np.mean(acc), np.std(acc)])
    idx_label[count] = dataset_name
    count+=1
    
df_ols = pd.DataFrame(data, columns=header, index=[idx_label])
df_ols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 6>()
#       5 count=0
#       6 for dataset_name in datasets: # For this specific dataset
# ----> 7     df = results_df.loc[results_df['dataset_name'] == dataset_name] # get simulation results
#       9     # converting confusion matrices to numpy matrix
#      10     cm_ts = np.array([array for array in df['cm_ts'].values])
#
# NameError: name 'results_df' is not defined

# %% [markdown]
# # Comparing results:

# %%
header = ['Dataset', 'Model']+list(df_ols.columns)

temp_rols = df_rols.rename_axis('Dataset').reset_index().loc[:,[x for x in header if x!='Model']]
temp_rols.insert(1,'Model',['ROLS']*len(datasets.keys()))

temp_ols = df_ols.rename_axis('Dataset').reset_index()
temp_ols.insert(1,'Model',['OLS']*len(datasets.keys()))

print(
    pd.concat([temp_ols,temp_rols]).sort_index()
) # TODO: display
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 header = ['Dataset', 'Model']+list(df_ols.columns)
#       3 temp_rols = df_rols.rename_axis('Dataset').reset_index().loc[:,[x for x in header if x!='Model']]
#       4 temp_rols.insert(1,'Model',['ROLS']*len(datasets.keys()))
#
# NameError: name 'df_ols' is not defined
