# %%
from devcode.analysis.results import process_results
from devcode.utils import load_csv_as_pandas

# %% [markdown]
# #### 1. Global LSC results

# %%
global_ols_results_file = f"results/global-results/ols"
df_results = load_csv_as_pandas(global_ols_results_file)
process_results(df_results)
# Out:
# vc2c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eigenvalues'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### 2. Regional LSC results

# %%
regional_ols_results_file = f"results/regional-results/ols"
df_results = load_csv_as_pandas(regional_ols_results_file)
process_results(df_results)
# Out:
# vc2c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eigenvalues'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
regional_results_file = f"results/regional-results/temp_rlssvm/results"
df_results = load_csv_as_pandas(global_results_file)
process_results(df_results)
# Out:
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) complex128
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) float64
#
# pk
# (97,) complex128
#
# pk
# (97,) float64
#
# pk
# ...
